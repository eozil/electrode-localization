# %%
cmap = plt.cm.get_cmap("jet").copy()  # # create a colormap object
cmap.set_under('white',  alpha=0)
cmap_args = dict(cmap=cmap, vmin=1)   # # set colourbar map

cmap_gray = plt.cm.get_cmap("gray").copy()  # # create a colormap object
cmap_gray.set_under(color='none')
# cmap_gray_args = dict(cmap=cmap_gray, vmin=0.5)   # # set colourbar map
